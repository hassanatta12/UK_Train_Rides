# %% [markdown]
# # import necessery Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Read the data

# %%
data=pd.read_csv(r'C:\Users\Qaiaty store\\Desktop\\Depi\UK Train Rides\railway.csv')
data
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 2      f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27
# 3      b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36
# 4      2be00b45-0762-485e-a7a3       2023-12-27         18:22:56
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0            Online    Contactless    Adult     Standard     Advance     43
# ...

# %% [markdown]
# # Columns in data & Data types

# %%
data.columns
# Out:
# Index(['Transaction ID', 'Date of Purchase', 'Time of Purchase',
#        'Purchase Type', 'Payment Method', 'Railcard', 'Ticket Class',
#        'Ticket Type', 'Price', 'Departure Station', 'Arrival Destination',
#        'Date of Journey', 'Departure Time', 'Arrival Time',
#        'Actual Arrival Time', 'Journey Status', 'Reason for Delay',
#        'Refund Request'],
#       dtype='object')

# %%
dtypes = pd.DataFrame(data.dtypes , columns=['Data type']).reset_index(names=['Column Name'])
dtypes
# Out:
#             Column Name Data type
# 0        Transaction ID    object
# 1      Date of Purchase    object
# 2      Time of Purchase    object
# 3         Purchase Type    object
# 4        Payment Method    object
# 5              Railcard    object
# 6          Ticket Class    object
# 7           Ticket Type    object
# 8                 Price     int64
# 9     Departure Station    object
# 10  Arrival Destination    object
# 11      Date of Journey    object
# 12       Departure Time    object
# 13         Arrival Time    object
# 14  Actual Arrival Time    object
# 15       Journey Status    object
# 16     Reason for Delay    object
# 17       Refund Request    object

# %%
data.drop('Transaction ID', axis= 1 , inplace=True)

# %% [markdown]
# # NFO & Describ of data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31653 entries, 0 to 31652
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date of Purchase     31653 non-null  object
#  1   Time of Purchase     31653 non-null  object
#  2   Purchase Type        31653 non-null  object
#  3   Payment Method       31653 non-null  object
#  4   Railcard             10735 non-null  object
#  5   Ticket Class         31653 non-null  object
#  6   Ticket Type          31653 non-null  object
#  7   Price                31653 non-null  int64
#  8   Departure Station    31653 non-null  object
#  9   Arrival Destination  31653 non-null  object
#  10  Date of Journey      31653 non-null  object
#  11  Departure Time       31653 non-null  object
#  12  Arrival Time         31653 non-null  object
#  13  Actual Arrival Time  29773 non-null  object
#  14  Journey Status       31653 non-null  object
# ...

# %%
data.describe()
# Out:
#               Price
# count  31653.000000
# mean      23.439200
# std       29.997628
# min        1.000000
# 25%        5.000000
# 50%       11.000000
# 75%       35.000000
# max      267.000000

# %% [markdown]
# # Check null & dublicated Values

# %%
pd.DataFrame({'Number of Missing Values':data.isnull().sum(),'Percentage Of Missing Values (%)':(data.isnull().sum() / data.shape[0]) * 100})
# Out:
#                      Number of Missing Values  \
# Date of Purchase                            0
# Time of Purchase                            0
# Purchase Type                               0
# Payment Method                              0
# Railcard                                20918
# Ticket Class                                0
# Ticket Type                                 0
# Price                                       0
# Departure Station                           0
# Arrival Destination                         0
# Date of Journey                             0
# Departure Time                              0
# Arrival Time                                0
# Actual Arrival Time                      1880
# Journey Status                              0
# Reason for Delay                        27481
# Refund Request                              0
#
#                      Percentage Of Missing Values (%)
# Date of Purchase                             0.000000
# ...

# %%
data[data.duplicated]
# Out:
#       Date of Purchase Time of Purchase Purchase Type Payment Method  \
# 970         2024-01-05         06:36:12       Station    Credit Card
# 1063        2024-01-05         14:33:29       Station     Debit Card
# 1950        2024-01-08         20:28:45        Online    Credit Card
# 2334        2024-01-10         08:28:00        Online    Credit Card
# 6356        2024-01-24         15:12:03       Station    Contactless
# 12416       2024-02-10         17:25:24        Online    Contactless
# 21668       2024-03-23         09:30:48       Station    Credit Card
# 24315       2024-04-03         07:45:23        Online     Debit Card
#
#        Railcard Ticket Class Ticket Type  Price      Departure Station  \
# 970         NaN     Standard     Anytime    151  Liverpool Lime Street
# 1063   Disabled     Standard     Anytime      9          London Euston
# 1950        NaN     Standard     Advance      8      London St Pancras
# ...

# %% [markdown]
# # handle null values

# %%
data["Railcard"].fillna('N/A',inplace=True)

# %%
data['Actual Arrival Time'].fillna("00:00:00",inplace=True)

# %%
data['Reason for Delay'].fillna('Arrived',inplace=True)

# %%
data['Reason for Delay'].fillna('Arrived',inplace=True)

# %% [markdown]
# # Check null after handling

# %%
pd.DataFrame({'Number of Missing Values':data.isnull().sum(),'Percentage Of Missing Values (%)':(data.isnull().sum() / data.shape[0]) * 100})
# Out:
#                      Number of Missing Values  \
# Date of Purchase                            0
# Time of Purchase                            0
# Purchase Type                               0
# Payment Method                              0
# Railcard                                    0
# Ticket Class                                0
# Ticket Type                                 0
# Price                                       0
# Departure Station                           0
# Arrival Destination                         0
# Date of Journey                             0
# Departure Time                              0
# Arrival Time                                0
# Actual Arrival Time                         0
# Journey Status                              0
# Reason for Delay                            0
# Refund Request                              0
#
#                      Percentage Of Missing Values (%)
# Date of Purchase                                  0.0
# ...

# %%
data.to_csv("C:\\Users\\Qaiaty store\\Desktop\\Depi\\UK Train Rides\\clean railway.csv",index=False)
